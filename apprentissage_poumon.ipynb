# %%
install.packages("data.table")

load("data_param.RData")
load("data_conc.RData")
load("data_O2.RData")
# Out:
# Installing package into ‘/home/eloise/R/i686-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   impossible d'ouvrir l'URL 'https://cran.r-project.org/src/contrib/PACKAGES'”Warning message:
# “package ‘data.table’ is not available (for R version 3.4.2)”

# %%
params_table$y <- with(params_table,ifelse(taub_end==0.75,0,1))
params_table
# Out:
#    T   dt   taub_start taub_end taub_dgt y
# 1  100 0.01 0.75       0.75     50       0
# 2  100 0.01 0.75       0.75     50       0
# 3  100 0.01 0.75       0.75     50       0
# 4  100 0.01 0.75       0.75     50       0
# 5  100 0.01 0.75       0.75     50       0
# 6  100 0.01 0.75       0.75     50       0
# 7  100 0.01 0.75       0.68     50       1
# 8  100 0.01 0.75       0.61     50       1
# 9  100 0.01 0.75       0.54     50       1
# 10 100 0.01 0.75       0.47     50       1

# %%
t(table_conc[2,])
# Out:
#        2
# X1     0.1503846
# X2     0.1499178
# X3     0.1504116
# X4     0.1496756
# X5     0.1501334
# X6     0.1526550
# X7     0.1509347
# X8     0.1520558
# X9     0.1486928
# X10    0.1520602
# X11    0.1522386
# X12    0.1505875
# X13    0.1504129
# X14    0.1513185
# X15    0.1527240
# X16    0.1525864
# X17    0.1508312
# X18    0.1539462
# X19    0.1524398
# X20    0.1508682
# X21    0.1517356
# X22    0.1520878
# X23    0.1521664
# X24    0.1524643
# X25    0.1531979
# X26    0.1538295
# X27    0.1527279
# X28    0.1535033
# X29    0.1521080
# X30    0.1525486
# ⋮      ⋮
# X9971  0.1364386
# X9972  0.1347363
# X9973  0.1340433
# X9974  0.1344326
# X9975  0.1365435
# X9976  0.1352290
# X9977  0.1342650
# X9978  0.1343371
# X9979  0.1345812
# X9980  0.1331786
# X9981  0.1344392
# X9982  0.1349900
# X9983  0.1356507
# X9984  0.1336218
# X9985  0.1326174
# X9986  0.1332848
# X9987  0.1344943
# X9988  0.1345519
# X9989  0.1358044
# X9990  0.1328194
# X9991  0.1358712
# ...

# %%
data.train.static <- OnlineSuperLearner::Data.Static$new(dataset = table_conc)

# %%
W <- OnlineSuperLearner::RandomVariable$new(formula = W ~ Y_lag_1 + A_lag_1 +  W_lag_1 + Y_lag_2, family = 'gaussian')
# Out:
# [1] "list"

# %%
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): taille de 'fmt' au-delà de la taille de format maximale 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
# ...
